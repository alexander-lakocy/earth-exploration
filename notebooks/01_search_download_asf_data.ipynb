# %% [markdown]
# # Use ASF Search to find SAR data from Sentinel-1

# %%
import asf_search as asf
import folium
import numpy as np

# %%
asf.__version__
# Out:
# '8.0.1'

# %% [markdown]
# ## Perform first quick search

# %%
search_params = {
    "platform": asf.PLATFORM.SENTINEL1,
    "maxResults": 20,
}

# %%
count = asf.search_count(**search_params)
print(f"Found {count:,} results for given input parameters")
# Out:
# Found 175,956,696 results for given input parameters

# %%
results = asf.search(**search_params)

# %% [markdown]
# ### Mess around with ASF search results

# %%
print(type(results))
print("Results: ", *results.__dict__.keys(), sep="\n\t")
print(type(results.data))
print(len(results.data))
print(type(results.data[0]))
print("Data[0]: ", *results.data[0].__dict__.keys(), sep="\n\t")
print("Data[0].meta: ", *results.data[0].meta.keys(), sep="\n\t")
print("Data[0].properties: ", *results.data[0].properties.keys(), sep="\n\t")
print("Data[0].properties.polarization: ", results.data[0].properties["polarization"], sep="\n\t")
print("Data[0].properties.orbit: ", results.data[0].properties["orbit"], sep="\n\t")
print("Data[0].properties.processingDate: ", results.data[0].properties["processingDate"], sep="\n\t")
print("Data[0].properties.lat&long: ", results.data[0].properties["centerLat"], results.data[0].properties["centerLon"], sep="\n\t")
print("Data[0].geometry: ", *results.data[0].geometry.items(), sep="\n\t")
# Out:
# <class 'asf_search.ASFSearchResults.ASFSearchResults'>
# Results:
# 	data
# 	searchOptions
# 	searchComplete
# <class 'list'>
# 20
# <class 'asf_search.Products.S1Product.S1Product'>
# Data[0]:
# 	meta
# 	umm
# 	properties
# 	geometry
# 	baseline
# 	session
# Data[0].meta:
# 	concept-type
# 	concept-id
# 	revision-id
# 	native-id
# 	collection-concept-id
# 	provider-id
# 	format
# 	revision-date
# Data[0].properties:
# 	centerLat
# 	centerLon
# 	stopTime
# 	fileID
# 	flightDirection
# 	pathNumber
# 	processingLevel
# 	url
# 	startTime
# 	sceneName
# 	browse
# 	platform
# 	bytes
# 	md5sum
# 	frameNumber
# 	granuleType
# 	orbit
# 	polarization
# 	processingDate
# 	sensor
# 	groupID
# 	pgeVersion
# 	fileName
# 	beamModeType
# 	s3Urls
# Data[0].properties.polarization:
# 	VV+VH
# Data[0].properties.orbit:
# 	57195
# Data[0].properties.processingDate:
# 	2024-12-28T16:49:53Z
# Data[0].properties.lat&long:
# 	72.3396
# 	6.5489
# Data[0].geometry:
# 	('coordinates', [[[1.965806, 72.766342], [3.571899, 71.244942], [10.905669, 71.819344], [9.912877, 73.377647], [1.965806, 72.766342]]])
# 	('type', 'Polygon')
# type(Data.geojson()):  <class 'dict'>
# len(Data.geojson()):  2

# %%
geo_json = results.geojson()
print("type(Data.geojson()): ", type(geo_json))
print("len(Data.geojson()): ", len(geo_json))
# print(*[f"{k}: {v}, {type(v) = }" for k, v in geo_json.items()], sep="\n\n")
print("geo_json['features']: ", type(geo_json['features']), len(geo_json['features']), sep="\n")
for datascene in geo_json["features"]:
    for k, v in datascene.items():
        if isinstance(v, dict):
            print(f"{k}:")
            for k1, v1 in v.items():
                print(f"\t{k1}: {v1}")
        else:
            print(f"{k}: {v}")
        print("")
# print(*geo_json['features'], sep="\n")
# Out:
# type(Data.geojson()):  <class 'dict'>
# len(Data.geojson()):  2
# geo_json['features']:
# <class 'list'>
# 20
# type: Feature
#
# geometry:
# 	coordinates: [[[1.965806, 72.766342], [3.571899, 71.244942], [10.905669, 71.819344], [9.912877, 73.377647], [1.965806, 72.766342]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 72.3396
# 	centerLon: 6.5489
# 	stopTime: 2024-12-28T16:50:19Z
# 	fileID: S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65-OCN
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: OCN
# 	url: https://datapool.asf.alaska.edu/OCN/SA/S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65.zip
# 	startTime: 2024-12-28T16:49:53Z
# 	sceneName: S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 14214592
# 	md5sum: e50e77ebad8eaf07821985a57e8f469f
# 	frameNumber: 235
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:49:53Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0235_0240_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-ocn-1e29d408/S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[1.965806, 72.766342], [3.571899, 71.244942], [10.905669, 71.819344], [9.912877, 73.377647], [1.965806, 72.766342]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 72.3396
# 	centerLon: 6.5489
# 	stopTime: 2024-12-28T16:50:19Z
# 	fileID: S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65-METADATA_OCN
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: METADATA_OCN
# 	url: https://datapool.asf.alaska.edu/METADATA_OCN/SA/S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65.iso.xml
# 	startTime: 2024-12-28T16:49:53Z
# 	sceneName: S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 44118
# 	md5sum: 2f9d3c3d79b4942b2288c8df78623bb8
# 	frameNumber: 235
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:49:53Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0235_0240_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65.iso.xml
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_OCN__2SDV_20241228T164953_20241228T165019_057195_0708B3_3D65.iso.xml']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[3.571984, 71.244858], [4.89924, 69.794357], [11.731437, 70.339859], [10.903462, 71.81913], [3.571984, 71.244858]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 70.8339
# 	centerLon: 7.7415
# 	stopTime: 2024-12-28T16:49:53Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164928_20241228T164953_057195_0708B3_AC4C-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164928_20241228T164953_057195_0708B3_AC4C.zip
# 	startTime: 2024-12-28T16:49:28Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164928_20241228T164953_057195_0708B3_AC4C
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 884295049
# 	md5sum: 330330275ca2fe77848862b7f3872022
# 	frameNumber: 230
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:49:28Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0230_0235_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164928_20241228T164953_057195_0708B3_AC4C.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164928_20241228T164953_057195_0708B3_AC4C.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[4.899314, 69.794273], [6.075327, 68.33667], [12.469373, 68.857986], [11.727551, 70.339539], [4.899314, 69.794273]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 69.3639
# 	centerLon: 8.7637
# 	stopTime: 2024-12-28T16:49:28Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB-METADATA_GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: METADATA_GRD_HD
# 	url: https://datapool.asf.alaska.edu/METADATA_GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB.iso.xml
# 	startTime: 2024-12-28T16:49:03Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 59037
# 	md5sum: 3eb640b6ea02dda7013ec766714e472e
# 	frameNumber: 225
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:49:03Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0225_0230_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB.iso.xml
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB.iso.xml']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[4.899314, 69.794273], [6.075327, 68.33667], [12.469373, 68.857986], [11.727551, 70.339539], [4.899314, 69.794273]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 69.3639
# 	centerLon: 8.7637
# 	stopTime: 2024-12-28T16:49:28Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB.zip
# 	startTime: 2024-12-28T16:49:03Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB
# 	browse: ['https://datapool.asf.alaska.edu/BROWSE/SA/S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB.jpg']
# 	platform: Sentinel-1A
# 	bytes: 883786208
# 	md5sum: 9469e5480c7f41232cbae735f0612945
# 	frameNumber: 225
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:49:03Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0225_0230_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164903_20241228T164928_057195_0708B3_BAAB.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[6.075394, 68.336578], [7.128289, 66.873138], [13.140156, 67.374306], [12.4677, 68.857788], [6.075394, 68.336578]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 67.89
# 	centerLon: 9.6781
# 	stopTime: 2024-12-28T16:49:03Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164838_20241228T164903_057195_0708B3_7303-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164838_20241228T164903_057195_0708B3_7303.zip
# 	startTime: 2024-12-28T16:48:38Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164838_20241228T164903_057195_0708B3_7303
# 	browse: ['https://datapool.asf.alaska.edu/BROWSE/SA/S1A_IW_GRDH_1SDV_20241228T164838_20241228T164903_057195_0708B3_7303.jpg']
# 	platform: Sentinel-1A
# 	bytes: 847156680
# 	md5sum: 2346f060b2036eb5f7a9440cc00cb142
# 	frameNumber: 220
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:48:38Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0220_0225_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164838_20241228T164903_057195_0708B3_7303.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164838_20241228T164903_057195_0708B3_7303.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[9.772588, 62.459373], [10.495148, 60.97892], [15.36268, 61.426117], [14.878356, 62.916042], [9.772588, 62.459373]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 61.9677
# 	centerLon: 12.6127
# 	stopTime: 2024-12-28T16:47:23Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164658_20241228T164723_057195_0708B3_3B89-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164658_20241228T164723_057195_0708B3_3B89.zip
# 	startTime: 2024-12-28T16:46:58Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164658_20241228T164723_057195_0708B3_3B89
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 941626131
# 	md5sum: 65b4b80aaeb0fe11bd2284e73ad9e1b5
# 	frameNumber: 200
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:46:58Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0200_0205_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164658_20241228T164723_057195_0708B3_3B89.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164658_20241228T164723_057195_0708B3_3B89.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[10.495191, 60.978832], [11.167775, 59.4958], [15.819242, 59.934967], [15.361043, 61.425907], [10.495191, 60.978832]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 60.4801
# 	centerLon: 13.1978
# 	stopTime: 2024-12-28T16:46:58Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178-METADATA_GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: METADATA_GRD_HD
# 	url: https://datapool.asf.alaska.edu/METADATA_GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178.iso.xml
# 	startTime: 2024-12-28T16:46:33Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 59041
# 	md5sum: d2f8beecfabb3af5aae5925afd3da3fe
# 	frameNumber: 195
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:46:33Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0195_0200_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178.iso.xml
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178.iso.xml']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[10.495191, 60.978832], [11.167775, 59.4958], [15.819242, 59.934967], [15.361043, 61.425907], [10.495191, 60.978832]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 60.4801
# 	centerLon: 13.1978
# 	stopTime: 2024-12-28T16:46:58Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178.zip
# 	startTime: 2024-12-28T16:46:33Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178
# 	browse: ['https://datapool.asf.alaska.edu/BROWSE/SA/S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178.jpg']
# 	platform: Sentinel-1A
# 	bytes: 1016344932
# 	md5sum: 932283124a202dd658f8e8db3e617aac
# 	frameNumber: 195
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:46:33Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0195_0200_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164633_20241228T164658_057195_0708B3_F178.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[11.167815, 59.495708], [11.805751, 58.011345], [16.261662, 58.443504], [15.8175, 59.934742], [11.167815, 59.495708]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 58.9914
# 	centerLon: 13.7516
# 	stopTime: 2024-12-28T16:46:33Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B-METADATA_GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: METADATA_GRD_HD
# 	url: https://datapool.asf.alaska.edu/METADATA_GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B.iso.xml
# 	startTime: 2024-12-28T16:46:08Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B
# 	browse: ['https://datapool.asf.alaska.edu/BROWSE/SA/S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B.jpg']
# 	platform: Sentinel-1A
# 	bytes: 59041
# 	md5sum: 31a565b9b735c02d09d5500475964deb
# 	frameNumber: 190
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:46:08Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0190_0195_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B.iso.xml
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B.iso.xml']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[11.167815, 59.495708], [11.805751, 58.011345], [16.261662, 58.443504], [15.8175, 59.934742], [11.167815, 59.495708]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 58.9914
# 	centerLon: 13.7516
# 	stopTime: 2024-12-28T16:46:33Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B.zip
# 	startTime: 2024-12-28T16:46:08Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B
# 	browse: ['https://datapool.asf.alaska.edu/BROWSE/SA/S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B.jpg']
# 	platform: Sentinel-1A
# 	bytes: 1011609174
# 	md5sum: cad5f5ade6018d96705da194105573a5
# 	frameNumber: 190
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:46:08Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0190_0195_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164608_20241228T164633_057195_0708B3_7E8B.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[11.805786, 58.011257], [12.406668, 56.524899], [16.685102, 56.951214], [16.259993, 58.443283], [11.805786, 58.011257]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 57.5016
# 	centerLon: 14.2789
# 	stopTime: 2024-12-28T16:46:08Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139-METADATA_GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: METADATA_GRD_HD
# 	url: https://datapool.asf.alaska.edu/METADATA_GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139.iso.xml
# 	startTime: 2024-12-28T16:45:43Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 59041
# 	md5sum: 93c5ac214517ee25ee890091033b9bcb
# 	frameNumber: 185
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:45:43Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0185_0190_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139.iso.xml
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139.iso.xml']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[11.805786, 58.011257], [12.406668, 56.524899], [16.685102, 56.951214], [16.259993, 58.443283], [11.805786, 58.011257]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 57.5016
# 	centerLon: 14.2789
# 	stopTime: 2024-12-28T16:46:08Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139.zip
# 	startTime: 2024-12-28T16:45:43Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 1023619458
# 	md5sum: 2f5b88ea608947e7cb86165bb4fba647
# 	frameNumber: 185
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:45:43Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0185_0190_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164543_20241228T164608_057195_0708B3_A139.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[17.1847, 53.9514], [13.4612, 53.6459], [14.1119, 51.7054], [17.672, 52.0032], [17.1847, 53.9514]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 52.8408
# 	centerLon: 15.6059
# 	stopTime: 2024-12-28T16:44:57Z
# 	fileID: S1A_IW_RAW__0SDV_20241228T164424_20241228T164457_057195_0708B3_D728-RAW
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: RAW
# 	url: https://datapool.asf.alaska.edu/RAW/SA/S1A_IW_RAW__0SDV_20241228T164424_20241228T164457_057195_0708B3_D728.zip
# 	startTime: 2024-12-28T16:44:24Z
# 	sceneName: S1A_IW_RAW__0SDV_20241228T164424_20241228T164457_057195_0708B3_D728
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 1622727506
# 	md5sum: b7cc481c4ccae4ce713f73c30f587a56
# 	frameNumber: 169
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:44:24Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0170_0175_057195_073
# 	pgeVersion: None
# 	fileName: S1A_IW_RAW__0SDV_20241228T164424_20241228T164457_057195_0708B3_D728.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-raw-98779950/S1A_IW_RAW__0SDV_20241228T164424_20241228T164457_057195_0708B3_D728.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[13.511861, 53.546307], [14.025948, 52.054836], [17.859741, 52.469387], [17.479414, 53.96384], [13.511861, 53.546307]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 53.0246
# 	centerLon: 15.7112
# 	stopTime: 2024-12-28T16:44:53Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01-METADATA_GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: METADATA_GRD_HD
# 	url: https://datapool.asf.alaska.edu/METADATA_GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01.iso.xml
# 	startTime: 2024-12-28T16:44:28Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01
# 	browse: ['https://datapool.asf.alaska.edu/BROWSE/SA/S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01.jpg']
# 	platform: Sentinel-1A
# 	bytes: 59041
# 	md5sum: f2dcf526add61a2358b2ed6ed0668743
# 	frameNumber: 170
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:44:28Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0170_0175_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01.iso.xml
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01.iso.xml']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[13.511861, 53.546307], [14.025948, 52.054836], [17.859741, 52.469387], [17.479414, 53.96384], [13.511861, 53.546307]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 53.0246
# 	centerLon: 15.7112
# 	stopTime: 2024-12-28T16:44:53Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01.zip
# 	startTime: 2024-12-28T16:44:28Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01
# 	browse: ['https://datapool.asf.alaska.edu/BROWSE/SA/S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01.jpg']
# 	platform: Sentinel-1A
# 	bytes: 1014864876
# 	md5sum: 68d5d32c24151989073e116772403aee
# 	frameNumber: 170
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:44:28Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0170_0175_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164428_20241228T164453_057195_0708B3_9D01.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[17.5626, 52.4483], [13.9667, 52.1488], [14.5887, 50.2064], [18.0346, 50.4992], [17.5626, 52.4483]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 51.3393
# 	centerLon: 16.0368
# 	stopTime: 2024-12-28T16:44:32Z
# 	fileID: S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1-RAW
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: RAW
# 	url: https://datapool.asf.alaska.edu/RAW/SA/S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1.zip
# 	startTime: 2024-12-28T16:43:59Z
# 	sceneName: S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 1592140214
# 	md5sum: e7058ef1f0d52331b4b6210a4cf607d0
# 	frameNumber: 164
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:43:59Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0165_0170_057195_073
# 	pgeVersion: None
# 	fileName: S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-raw-98779950/S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1.zip']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[17.5626, 52.4483], [13.9667, 52.1488], [14.5887, 50.2064], [18.0346, 50.4992], [17.5626, 52.4483]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 51.3393
# 	centerLon: 16.0368
# 	stopTime: 2024-12-28T16:44:32Z
# 	fileID: S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1-METADATA_RAW
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: METADATA_RAW
# 	url: https://datapool.asf.alaska.edu/METADATA_RAW/SA/S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1.iso.xml
# 	startTime: 2024-12-28T16:43:59Z
# 	sceneName: S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 41592
# 	md5sum: 6f3c4f024d0a0df3424d33178c69a628
# 	frameNumber: 164
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:43:59Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0165_0170_057195_073
# 	pgeVersion: None
# 	fileName: S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1.iso.xml
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_RAW__0SDV_20241228T164359_20241228T164432_057195_0708B3_72E1.iso.xml']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[14.025977, 52.054745], [14.525579, 50.56284], [18.23505, 50.974709], [17.858162, 52.469151], [14.025977, 52.054745]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 51.5305
# 	centerLon: 16.1538
# 	stopTime: 2024-12-28T16:44:28Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7-METADATA_GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: METADATA_GRD_HD
# 	url: https://datapool.asf.alaska.edu/METADATA_GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7.iso.xml
# 	startTime: 2024-12-28T16:44:03Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7
# 	browse: None
# 	platform: Sentinel-1A
# 	bytes: 59041
# 	md5sum: 24d15f7ce47a967bf0efa24145dd1063
# 	frameNumber: 165
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:44:03Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0165_0170_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7.iso.xml
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7.iso.xml']
#
# type: Feature
#
# geometry:
# 	coordinates: [[[14.025977, 52.054745], [14.525579, 50.56284], [18.23505, 50.974709], [17.858162, 52.469151], [14.025977, 52.054745]]]
# 	type: Polygon
#
# properties:
# 	centerLat: 51.5305
# 	centerLon: 16.1538
# 	stopTime: 2024-12-28T16:44:28Z
# 	fileID: S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7-GRD_HD
# 	flightDirection: ASCENDING
# 	pathNumber: 73
# 	processingLevel: GRD_HD
# 	url: https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7.zip
# 	startTime: 2024-12-28T16:44:03Z
# 	sceneName: S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7
# 	browse: ['https://datapool.asf.alaska.edu/BROWSE/SA/S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7.jpg']
# 	platform: Sentinel-1A
# 	bytes: 984655558
# 	md5sum: f37c382dfee4745e7fb854716d415d93
# 	frameNumber: 165
# 	granuleType: SENTINEL_1A_FRAME
# 	orbit: 57195
# 	polarization: VV+VH
# 	processingDate: 2024-12-28T16:44:03Z
# 	sensor: C-SAR
# 	groupID: S1A_IWDV_0165_0170_057195_073
# 	pgeVersion: 003.90
# 	fileName: S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7.zip
# 	beamModeType: IW
# 	s3Urls: ['s3://asf-ngap2w-p-s1-grd-7d1b4348/S1A_IW_GRDH_1SDV_20241228T164403_20241228T164428_057195_0708B3_59F7.zip']

# %%
print(results[0])
# Out:
# {
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           80.4489,
#           47.479
#         ],
#         [
#           77.2056,
#           47.1947
#         ],
#         [
#           77.8421,
#           44.9267
#         ],
#         [
#           80.9528,
#           45.2062
#         ],
#         [
#           80.4489,
#           47.479
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "properties": {
#     "beamModeType": "IW",
#     "browse": null,
#     "bytes": 1903866818,
#     "centerLat": 46.2131,
#     "centerLon": 79.1128,
#     "fileID": "S1A_IW_RAW__0SDV_20241104T123544_20241104T123621_056405_06E94C_6864-RAW",
#     "fileName": "S1A_IW_RAW__0SDV_20241104T123544_20241104T123621_056405_06E94C_6864.zip",
#     "flightDirection": "ASCENDING",
#     "frameNumber": 147,
#     "granuleType": "SENTINEL_1A_FRAME",
#     "groupID": "S1A_IWDV_0147_0154_056405_158",
#     "md5sum": "13a9ebe253ca8105912ed73f527f0a77",
#     "orbit": 56405,
#     "pathNumber": 158,
#     "pgeVersion": null,
#     "platform": "Sentinel-1A",
#     "polarization": "VV+VH",
#     "processingDate": "2024-11-04T12:35:44Z",
#     "processingLevel": "RAW",
#     "s3Urls": [
#       "s3://asf-ngap2w-p-s1-raw-98779950/S1A_IW_RAW__0SDV_20241104T123544_20241104T123621_056405_06E94C_6864.zip"
#     ],
#     "sceneName": "S1A_IW_RAW__0SDV_20241104T123544_20241104T123621_056405_06E94C_6864",
#     "sensor": "C-SAR",
#     "startTime": "2024-11-04T12:35:44Z",
#     "stopTime": "2024-11-04T12:36:21Z",
#     "url": "https://datapool.asf.alaska.edu/RAW/SA/S1A_IW_RAW__0SDV_20241104T123544_20241104T123621_056405_06E94C_6864.zip"
#   },
#   "type": "Feature"
# }

# %% [markdown]
# ## Geographic Search
#
# ### Define Area of Interest - Rogue Valley, Oregon

# %%
# Created using Vertex search click on map
aoi = "POLYGON((-123.0252 42.3902,-122.5958 42.1035,-122.4631 42.155,-122.8968 42.4694,-123.0252 42.3902))"

# %%
search_params = {
    "platform": asf.PLATFORM.SENTINEL1,
    "maxResults": 200,
    "start": "2018-06-01",
    "end": "2018-06-07",
    "processingLevel": asf.PRODUCT_TYPE.SLC,
}

# %%
# Count results without geometry filter
count_results = asf.search_count(**search_params)
print(f"Found {count_results:,} results for given input parameters")
# Out:
# Found 5,445 results for given input parameters

# %% [markdown]
# ### Perform Geometric Search

# %%
geo_results = asf.geo_search(intersectsWith=aoi, **search_params)
print(f"({len(geo_results)}) results found")
# Out:
# (2) results found

# %%
print(geo_results[0].properties["centerLat"], geo_results[0].properties["centerLon"])
latest_result_date = geo_results[0].properties["processingDate"]
print(f"{latest_result_date = }")
# Out:
# 42.0993 -122.138
# latest_result_date = '2018-06-06T14:14:41Z'

# %% [markdown]
# ### Find `stack` of results to compare over time

# %%
stack = geo_results[0].stack()

print(f"{len(stack)} product results found in stack")

for i, r in enumerate(stack):
    if "2018-06-06" in r.properties["processingDate"]:
        print(f"({i}): {r.properties["processingDate"]}\t{r.properties['temporalBaseline']}")
    if r.properties["processingDate"] == latest_result_date:
        print(f"({i}): {r.properties["processingDate"]}\t{r.properties['temporalBaseline']}")
        break
# Out:
# 273 product results found in stack
# (76): 2018-06-06T14:14:41Z	0
# (76): 2018-06-06T14:14:41Z	0

# %%
for i in range(25):
    print(f"{stack[i].properties["processingDate"]}: {stack[i].properties["temporalBaseline"]}")
i = -1
print(f"{stack[i].properties["processingDate"]}: {stack[i].properties["temporalBaseline"]}")
# Out:
# 2015-02-22T14:14:31Z: -1200
# 2015-02-22T14:14:06Z: -1200
# 2015-03-06T14:14:30Z: -1188
# 2015-03-18T14:14:31Z: -1176
# 2015-03-30T14:14:32Z: -1164
# 2015-03-30T14:14:06Z: -1164
# 2015-04-11T14:14:32Z: -1152
# 2015-04-11T14:14:07Z: -1152
# 2015-04-23T14:14:33Z: -1140
# 2015-04-23T14:14:07Z: -1140
# 2015-06-10T14:14:30Z: -1092
# 2015-07-04T14:14:31Z: -1068
# 2015-07-28T14:14:32Z: -1044
# 2015-08-21T14:14:34Z: -1020
# 2015-09-14T14:14:34Z: -996
# 2015-10-08T14:14:35Z: -972
# 2015-11-01T14:14:35Z: -948
# 2015-11-25T14:14:29Z: -924
# 2015-12-19T14:14:28Z: -900
# 2016-01-12T14:14:27Z: -876
# 2016-02-05T14:14:27Z: -852
# 2016-02-29T14:14:27Z: -828
# 2016-04-17T14:14:28Z: -780
# 2016-05-11T14:14:29Z: -756
# 2016-06-04T14:14:30Z: -732
# 2024-11-01T14:15:16Z: 2340

# %% [markdown]
# ### Plot Result

# %%
product = geo_results[0]
footprint = product.geojson()

# %%
print(type(footprint))
print(footprint.keys())
print(type(footprint["geometry"]))
print(footprint["geometry"].keys())
print(footprint["geometry"]["coordinates"])
coords_np = np.array(footprint["geometry"]["coordinates"])
long_mean = np.mean(coords_np[:, :, 0])
lat_mean = np.mean(coords_np[:, :, 1])
print(f"Mean lat: {lat_mean:0.4f},\tMean long: {long_mean:0.4f}")
# Out:
# <class 'dict'>
# dict_keys(['type', 'geometry', 'properties'])
# <class 'dict'>
# dict_keys(['coordinates', 'type'])
# [[[-120.842606, 41.083923], [-120.418518, 42.702103], [-123.48111, 43.094376], [-123.8255, 41.476665], [-120.842606, 41.083923]]]
# Mean lat: 41.8882,	Mean long: -121.8821

# %%
center_coords = [
    lat_mean, 
    long_mean,
]

# %%
m = folium.Map(location=center_coords, zoom_start=8)
folium.GeoJson(footprint, name="SAR Product Footprint").add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2b683c4b542e6d2d0460e77026b429c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2b683c4b542e6d2d0460e77026b429c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2b683c4b542e6d2d0460e77026b429c = L.map(
#                 &quot;map_c2b683c4b542e6d2d0460e77026b429c&quot;,
#                 {
#                     center: [41.888197999999996, -121.882068],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55017b46668410cf2964b8103809b9da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_55017b46668410cf2964b8103809b9da.addTo(map_c2b683c4b542e6d2d0460e77026b429c);
#
#
#
#         function geo_json_f446adb562a7f7c45baa6a017ffc1704_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f446adb562a7f7c45baa6a017ffc1704 = L.geoJson(null, {
#                 onEachFeature: geo_json_f446adb562a7f7c45baa6a017ffc1704_onEachFeature,
#
#         });
#
#         function geo_json_f446adb562a7f7c45baa6a017ffc1704_add (data) {
#             geo_json_f446adb562a7f7c45baa6a017ffc1704
#                 .addData(data);
#         }
#             geo_json_f446adb562a7f7c45baa6a017ffc1704_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-120.842606, 41.083923], [-120.418518, 42.702103], [-123.48111, 43.094376], [-123.8255, 41.476665], [-120.842606, 41.083923]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;beamModeType&quot;: &quot;IW&quot;, &quot;browse&quot;: null, &quot;bytes&quot;: 4664892613, &quot;centerLat&quot;: 42.0993, &quot;centerLon&quot;: -122.138, &quot;fileID&quot;: &quot;S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03-SLC&quot;, &quot;fileName&quot;: &quot;S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.zip&quot;, &quot;flightDirection&quot;: &quot;DESCENDING&quot;, &quot;frameNumber&quot;: 452, &quot;granuleType&quot;: &quot;SENTINEL_1A_FRAME&quot;, &quot;groupID&quot;: &quot;S1A_IWDV_0451_0458_022237_115&quot;, &quot;md5sum&quot;: &quot;fb8989f2be22b31e2dd776349578c1dd&quot;, &quot;orbit&quot;: 22237, &quot;pathNumber&quot;: 115, &quot;pgeVersion&quot;: &quot;002.90&quot;, &quot;platform&quot;: &quot;Sentinel-1A&quot;, &quot;polarization&quot;: &quot;VV+VH&quot;, &quot;processingDate&quot;: &quot;2018-06-06T14:14:41Z&quot;, &quot;processingLevel&quot;: &quot;SLC&quot;, &quot;s3Urls&quot;: [&quot;s3://asf-ngap2w-p-s1-slc-7b420b89/S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.zip&quot;], &quot;sceneName&quot;: &quot;S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03&quot;, &quot;sensor&quot;: &quot;C-SAR&quot;, &quot;startTime&quot;: &quot;2018-06-06T14:14:41Z&quot;, &quot;stopTime&quot;: &quot;2018-06-06T14:15:08Z&quot;, &quot;url&quot;: &quot;https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.zip&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#         geo_json_f446adb562a7f7c45baa6a017ffc1704.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_f446adb562a7f7c45baa6a017ffc1704.addTo(map_c2b683c4b542e6d2d0460e77026b429c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Try downloading result
# Ensure session is correctly authenticated

# %%
session = asf.ASFSession()

# %%
# geo_results[0].download(path="../data/sentinel-1", session=session)

# %% [markdown]
# ### Load result file

# %%
import rasterio
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import glob
from scipy.ndimage import zoom
from scipy.interpolate import griddata
from pathlib import Path
import xml.etree.ElementTree as ET

# %%
file_glob = glob.glob("../data/sentinel-1/*/measurement/*.tiff")

# %%
# Select .tiff file and get 
file_path = file_glob[0]
print(file_path)
file_path_p = Path(file_path)
print(file_path_p)

file_stem = file_path_p.stem
print(file_stem)
# Out:
# ../data/sentinel-1\S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.SAFE\measurement\s1a-iw1-slc-vh-20180606t141443-20180606t141508-022237-0267eb-001.tiff
# ..\data\sentinel-1\S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.SAFE\measurement\s1a-iw1-slc-vh-20180606t141443-20180606t141508-022237-0267eb-001.tiff
# s1a-iw1-slc-vh-20180606t141443-20180606t141508-022237-0267eb-001

# %%
product_path = file_path_p.parent.parent
print(product_path)
preview_path = product_path.joinpath("preview")
print(preview_path)
kml_files = glob.glob(f"{str(preview_path)}/*.kml")
kml_file = kml_files[0]
print(kml_file)
# Out:
# ..\data\sentinel-1\S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.SAFE
# ..\data\sentinel-1\S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.SAFE\preview
# ..\data\sentinel-1\S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.SAFE\preview\map-overlay.kml

# %%
# Find annotation data for measurement file
annotation_path = product_path / "annotation"
annotation_file = annotation_path / f"{file_stem}.xml"
print(annotation_file)
# Out:
# ..\data\sentinel-1\S1A_IW_SLC__1SDV_20180606T141441_20180606T141508_022237_0267EB_EC03.SAFE\annotation\s1a-iw1-slc-vh-20180606t141443-20180606t141508-022237-0267eb-001.xml

# %%
# Load XML and geolocation grid
ann_tree = ET.parse(annotation_file)
ann_root = ann_tree.getroot()
print(ann_root)
print(ann_root.tag)
print(ann_root.attrib)
print(type(ann_root))

glg_element = ann_root.find("geolocationGrid")

glgpl_element = glg_element.find("geolocationGridPointList")

geolocation_points = []
for i, point in enumerate(glgpl_element.findall("geolocationGridPoint")):
    line = int(point.find("line").text)
    pixel = int(point.find("pixel").text)
    lat = float(point.find("latitude").text)
    lon = float(point.find("longitude").text)
    geolocation_points.append((line, pixel, lat, lon))

geolocation_array = np.array(geolocation_points)
print(f"{geolocation_array.shape = }")
lines = geolocation_array[:, 0]
pixels = geolocation_array[:, 1]
lats = geolocation_array[:, 2]
lons = geolocation_array[:, 3]
# Out:
# <Element 'product' at 0x000001B6A00CF560>
# product
# {}
# <class 'xml.etree.ElementTree.Element'>
# geolocation_array.shape = (210, 4)

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))
axs[0].scatter(lines, pixels)
axs[0].set_xlabel("Line")
axs[0].set_ylabel("Pixel")

axs[1].scatter(lons, lats)
axs[1].set_xlabel("Longitude")
axs[1].set_ylabel("Latitude")
plt.show()

# %%
tree = ET.parse(kml_file)
root = tree.getroot()
namespaces = {"gx": "http://www.google.com/kml/ext/2.2"}
coordinates_tag = root.find(".//gx:LatLonQuad/coordinates", namespaces)
coordinates_text = coordinates_tag.text.strip()
coordinates = [
    tuple(map(float, coord.split(","))) for coord in coordinates_text.split()
]

print(coordinates)
# Out:
# [(-120.842606, 41.083923), (-123.8255, 41.476665), (-123.48111, 43.094376), (-120.418518, 42.702103)]

# %%
with rasterio.open(file_path, "r") as src:
    print(type(src))
    print(src.__dict__.items())
    print(f"{src.crs = }")
    sar_data = src.read(1)
    print(type(sar_data))
    print(sar_data.shape)
    transform = src.transform
    bounds = src.bounds
    print(f"{bounds = }")
# Out:
# <class 'rasterio.io.DatasetReader'>
# dict_items([])
# src.crs = None
# <class 'numpy.ndarray'>
# (13473, 21198)
# bounds = BoundingBox(left=0.0, bottom=13473.0, right=21198.0, top=0.0)

# %%
sar_data_shape = sar_data.shape

print(f"{lines.shape = }")
print(f"{pixels.shape = }")

target_lines, target_pixels = np.meshgrid(np.arange(sar_data_shape[0]), np.arange(sar_data_shape[1]), indexing="ij")
print(f"{target_lines.shape = }")
print(f"{target_pixels.shape = }")

grid_lat = griddata((lines, pixels), lats, (target_lines, target_pixels), method="linear")
grid_lon = griddata((lines, pixels), lons, (target_lines, target_pixels), method="linear")
print(f"{grid_lat.shape = }")
print(f"{grid_lon.shape = }")
# Out:
# lines.shape = (210,)
# pixels.shape = (210,)
# target_lines.shape = (13473, 21198)
# target_pixels.shape = (13473, 21198)
# grid_lat.shape = (13473, 21198)
# grid_lon.shape = (13473, 21198)

# %%
bound_coords = coordinates

# %%
print(f"{sar_data.nbytes / 1024 / 1024:0.1f} MB")
# Out:
# 2179.0 MB

# %%
sar_data_magnitude = np.abs(sar_data)
print(sar_data_magnitude.dtype)
# Out:
# float32

# %%
n = -1
n_reduce = 50
grid_lon_flat = grid_lon[:n, :n].flatten()[::n_reduce]
grid_lat_flat = grid_lat[:n, :n].flatten()[::n_reduce]
sar_data_flat = sar_data_magnitude[:n, :n].flatten()[::n_reduce]

# %%
plt.scatter(grid_lon_flat, grid_lat_flat, c=sar_data_flat)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
# plot_bounds = (bounds.left, bounds.right, bounds.bottom, bounds.top)
bc_np = np.array(bound_coords)
left = np.min(bc_np[:, 0])
right = np.max(bc_np[:, 0])
bottom = np.min(bc_np[:, 1])
top = np.max(bc_np[:, 1])

plot_bounds = (left, right, bottom, top)
print(plot_bounds)
# Out:
# (np.float64(-123.8255), np.float64(-120.418518), np.float64(41.083923), np.float64(43.094376))

# %%
print(f"{sar_data_magnitude.shape = }")
print(np.min(sar_data_magnitude))
print(np.max(sar_data_magnitude))
print(np.count_nonzero(sar_data_magnitude > 100))
plt.figure(figsize=(12, 8))
plt.imshow(np.log(sar_data_magnitude))  #, cmap="gray")  #, extent=plot_bounds)
plt.colorbar(label="Intensity")
plt.title("SAR Intensity VH")
plt.show()
# Out:
# sar_data_magnitude.shape = (13473, 21198)
# 0.0
# 1951.7787
# 5918609
# C:\Users\alakocy\AppData\Local\Temp\ipykernel_21840\2900570708.py:6: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(sar_data_magnitude))  #, cmap="gray")  #, extent=plot_bounds)

# %%
pc_crs = ccrs.PlateCarree()
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={"projection": pc_crs})
ax.set_extent(plot_bounds, crs=pc_crs)
img = ax.imshow(sar_data_magnitude, cmap="gray", extent=plot_bounds, transform=pc_crs)

ax.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor="black")
ax.add_feature(cfeature.BORDERS, linestyle=":", edgecolor="gray")
ax.add_feature(cfeature.STATES, linestyle="--", edgecolor="gray")

fig.suptitle("SAR Data Overlay\n2018-06-06 14:14:41Z 1SDV")
plt.colorbar(img, ax=ax, orientation="vertical", label="Intensity")
plt.show()
# Out:
# C:\Users\alakocy\AppData\Local\pypoetry\Cache\virtualenvs\earth-exploration-QkpwS6pU-py3.12\Lib\site-packages\cartopy\io\__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# C:\Users\alakocy\AppData\Local\pypoetry\Cache\virtualenvs\earth-exploration-QkpwS6pU-py3.12\Lib\site-packages\cartopy\io\__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# C:\Users\alakocy\AppData\Local\pypoetry\Cache\virtualenvs\earth-exploration-QkpwS6pU-py3.12\Lib\site-packages\cartopy\io\__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_1_states_provinces_lakes.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %%
block_size = 10
downsample_factor = 1 / block_size
sar_data_zoom = zoom(sar_data_magnitude, downsample_factor)

# %%
print(f"{sar_data_zoom.nbytes / 1024 / 1024:0.1f} MB")
# Out:
# 10.9 MB

# %%
def manual_downsample(data: np.ndarray, block_size: int) -> np.ndarray:
    orig_shape = data.shape
    new_shape = tuple([data.shape[0] // block_size, block_size, data.shape[1] // block_size, block_size])
    return data[:new_shape[0] * block_size, :new_shape[2] * block_size].reshape(new_shape).mean(axis=(1, 3))

# %%
sar_data_downsample = manual_downsample(sar_data_magnitude, block_size)

# %%
print(f"{sar_data_downsample.nbytes / 1024 / 1024:0.1f} MB")
# Out:
# 10.9 MB

# %%
new_transform = rasterio.Affine(
    transform.a / downsample_factor, transform.b, transform.c,
    transform.d, transform.e / downsample_factor, transform.f,
)

# %%
# new_width = int((bounds.right - bounds.left) / (transform.a * downsample_factor))
new_width = int((right - left) / (transform.a * downsample_factor))
# new_height = int((bounds.top - bounds.bottom) / (-transform.e * downsample_factor))
new_height = int((top - bottom) / (-transform.e * downsample_factor))

new_bounds = rasterio.transform.array_bounds(new_height, new_width, new_transform)
# print(f"{bounds = }")
print(f"{plot_bounds = }")
print(f"{new_bounds = }")
# Out:
# plot_bounds = (np.float64(-123.8255), np.float64(-120.418518), np.float64(41.083923), np.float64(43.094376))
# new_bounds = (0.0, -200.0, 340.0, 0.0)

# %%
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={"projection": ccrs.PlateCarree()})
ax.set_extent(new_bounds, crs=ccrs.PlateCarree())
img = ax.imshow(sar_data_downsample, cmap="gray", extent=new_bounds, transform=ccrs.PlateCarree())

ax.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor="black")
ax.add_feature(cfeature.BORDERS, linestyle=":", edgecolor="gray")
ax.add_feature(cfeature.STATES, linestyle="--", edgecolor="gray")

fig.suptitle("SAR Data Overlay\n2018-06-06 14:14:41Z 1SDV")
plt.colorbar(img, ax=ax, orientation="vertical", label="Intensity")
plt.show()
